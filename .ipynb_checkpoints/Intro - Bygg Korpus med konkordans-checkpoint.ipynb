# %% [markdown]
# ## Oppstartceller

# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %% [markdown]
# #### Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ### Import modules, maybe update with overwrite=True

# %%
update('graph_networkx_louvain')
import nbtext as nb
import graph_networkx_louvain as gnl
from graph_networkx_louvain import cutdown, make_collocation_graph
# %matplotlib inline
# Out:
# Updated file `D:\Documents\GitHub\Seminar-Mai-2019\graph_networkx_louvain.py`

# %% [markdown]
# ## Bygg korpus
#
# Korpuset er en definisjon av et korpus, og består av en samling URN-er.

# %% [markdown]
# Korpuset defineres med metadata som dewey, emneord, navn , år, etc. Her kan [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) være til god hjelp.
#
# Kommandoen er `book_urn()`

# %%
korpus = nb.book_urn( subject='religion', limit=200)
korpus[:10]
# Out:
# [[2011080908001, '', 'Middelalderens symboler', 1997],
#  [2009070904068, 'Hauge, Ragnar', 'Historien om LSD', 1990],
#  [2014072908092, 'Aakervik, Gunnhild', 'Dhal eller lapskaus?', 2010],
#  [2007051104025, 'Schjelderup, Kristian', 'Lys i mørket', 1965],
#  [2010042903009, 'Aarflot, Anne-Kristin', '[Grunnbok]', 1999],
#  [2015021308014,
#   'Taranger, Absalon',
#   'angelsaksiske kirkes indflydelse paa den norske',
#   1890],
#  [2013110806032, 'Eide, Unni Sefaniassen', 'Kosthold og livsstil', 2006],
#  [2016052608101,
#   'Kapelrud, Arvid S.',
#   'God and his friends in the Old Testament',
#   1979],
#  [2012061408041, 'Fett, Harry', 'Vår frue jomfru Maria', 1937],
#  [2014021008118, 'Bergsaker, Robert', 'Veien til Lhasa', 1992]]

# %% [markdown]
# ## Konkordans
#
# Kommando for å lage konkordanser fra et sett med URN-er er `urn_concordance()` (OBS! Korpuset bør være under 100 bøker for responsivitet)

# %%
nb.urn_concordance(word = 'kvinner', urns = korpus, before = 10, after = 10)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011080908001?searchText=kvinner' target='_blank' style='text-decoration:none'>Middelalderens symboler, , 1997</a>
#                 </td>
#                 <td>. Det samme finner vi i Frostatingsloven . 5 Men</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>kunne altså arve jord .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011080908001?searchText=kvinner' target='_blank' style='text-decoration:none'>Middelalderens symboler, , 1997</a>
#                 </td>
#                 <td>vel kjent at de aller fleste langhauger er bygget over</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011080908001?searchText=kvinner' target='_blank' style='text-decoration:none'>Middelalderens symboler, , 1997</a>
#                 </td>
#                 <td>2 ) . Som sikre primærgraver finner vi derimot både</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og menn . Lovene forteller jo at både kvinner og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011080908001?searchText=kvinner' target='_blank' style='text-decoration:none'>Middelalderens symboler, , 1997</a>
#                 </td>
#                 <td>både kvinner og menn . Lovene forteller jo at både</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og menn kunne arve jord , men det relativt store</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011080908001?searchText=kvinner' target='_blank' style='text-decoration:none'>Middelalderens symboler, , 1997</a>
#                 </td>
#                 <td>menn kunne arve jord , men det relativt store antallet</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>blant dem som haugene er reist over må vi kunne</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014072908092?searchText=kvinner' target='_blank' style='text-decoration:none'>Dhal eller lapskaus?, Aakervik, Gunnhild, 2010</a>
#                 </td>
#                 <td>fortelle om ga-at , en grøt som ble gitt til</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>rett etter fødselen , som kan ligne litt på norsk</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014072908092?searchText=kvinner' target='_blank' style='text-decoration:none'>Dhal eller lapskaus?, Aakervik, Gunnhild, 2010</a>
#                 </td>
#                 <td>i konsistens enn lever av okse eller lam . Gravide</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>kan like å spise kamellever for det motvirket kvalme i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051104025?searchText=kvinner' target='_blank' style='text-decoration:none'>Lys i mørket, Schjelderup, Kristian, 1965</a>
#                 </td>
#                 <td>eg glemmer alckri kra barneårene en av clisse enkle tromme</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>. I ^ lun kom okte i vkrt njem ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051104025?searchText=kvinner' target='_blank' style='text-decoration:none'>Lys i mørket, Schjelderup, Kristian, 1965</a>
#                 </td>
#                 <td>BvenBke BSBterkirke , nvor nettopp i 6 enne time tre</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>blir ordinert til preBter .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051104025?searchText=kvinner' target='_blank' style='text-decoration:none'>Lys i mørket, Schjelderup, Kristian, 1965</a>
#                 </td>
#                 <td>. Tenk på de første kristne , uredde , an6Bivlte</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og menn , som i tro på den levende Kristus</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010042903009?searchText=kvinner' target='_blank' style='text-decoration:none'>[Grunnbok], Aarflot, Anne-Kristin, 1999</a>
#                 </td>
#                 <td>hende . Men det hadde allereie vore mange menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som hadde åtvara dei .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010042903009?searchText=kvinner' target='_blank' style='text-decoration:none'>[Grunnbok], Aarflot, Anne-Kristin, 1999</a>
#                 </td>
#                 <td>Det gamle testamentet kan vi lese forteljingar om menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som fekk i oppdrag å tale på vegner av Gud</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010042903009?searchText=kvinner' target='_blank' style='text-decoration:none'>[Grunnbok], Aarflot, Anne-Kristin, 1999</a>
#                 </td>
#                 <td>afrikanarar hadde sprunge halvnakne og berrføtte i skogen, menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>med bambusrør og pil og boge . Nokre av dei</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010042903009?searchText=kvinner' target='_blank' style='text-decoration:none'>[Grunnbok], Aarflot, Anne-Kristin, 1999</a>
#                 </td>
#                 <td>til å føra alle han fann , både menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som høyrde Vegen ' til , i lekkjer til</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010042903009?searchText=kvinner' target='_blank' style='text-decoration:none'>[Grunnbok], Aarflot, Anne-Kristin, 1999</a>
#                 </td>
#                 <td>Mange av dei andre gjetarane var</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>( gopiar ) som var forelska i Krishna . Når</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013110806032?searchText=kvinner' target='_blank' style='text-decoration:none'>Kosthold og livsstil, Eide, Unni Sefaniassen, 2006</a>
#                 </td>
#                 <td>noen alderssykdom ( aldersdiabetes ) . Flere og flere både</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og menn utvikler i dag type 2 - diabetes i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013110806032?searchText=kvinner' target='_blank' style='text-decoration:none'>Kosthold og livsstil, Eide, Unni Sefaniassen, 2006</a>
#                 </td>
#                 <td>Det viser seg at divertikkelsykdommer oppstår mye hyppigere blant</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>enn blant menn . Som oftest er det i eldre</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013110806032?searchText=kvinner' target='_blank'

# %% [markdown]
# ## Hent fra fritekst
#
# Søk etter bøker på [nb.no](https://www.nb.no/search?q=), legg til *debugon* sammen med søkekriteriet. Kopier hele siden (ctrl-A) og lim inn resultatet mellom """ ... """ nedenfor. Kommandoen som brukes er `pure_urn(<tekst>)` som prøver å finne URN-er i alt mulig av tekst.

# %%
fritt_korpus = nb.pure_urn("""

--- lim inn tekst her, for ek


""")

# %%
fritt_korpus[:5]
# Out:
# []

# %%
nb.urn_concordance(word='arbeid', urns=fritt_korpus)
# Out:
# Parameter urns missing
# <table></table>
